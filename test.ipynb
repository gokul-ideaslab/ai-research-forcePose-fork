# %%
import numpy as np

# %%
keypoints = np.load(
    "data/data_2d_" + "force_pose" + "_" + "pt_coco" + ".npz", allow_pickle=True
)
keypoints_metadata = keypoints["metadata"].item()
keypoints_symmetry = keypoints_metadata["keypoints_symmetry"]
kps_left, kps_right = list(keypoints_symmetry[0]), list(keypoints_symmetry[1])

# %%
keypoints["metadata"]
# Out:
# array({'layout_name': 'coco', 'num_joints': 17, 'keypoints_symmetry': [[1, 3, 5, 7, 9, 11, 13, 15], [2, 4, 6, 8, 10, 12, 14, 16]]},
#       dtype=object)

# %%
data = np.load("yolo_kps/pred_force.npy")

data
# Out:
# array([[[ 0.2227042 , -0.51936346, -1.0315931 , -0.31833908,
#           0.10616937,  0.3527555 ]],
#
#        [[ 0.22081795, -0.52165645, -1.033421  , -0.31772742,
#           0.10707477,  0.3564393 ]],
#
#        [[ 0.22360162, -0.51915836, -1.0323331 , -0.3181288 ,
#           0.10493058,  0.3562302 ]],
#
#        ...,
#
#        [[ 0.2059526 , -0.50554514, -1.0367876 , -0.36016122,
#           0.09163357,  0.31614584]],
#
#        [[ 0.20238666, -0.50651896, -1.0382371 , -0.36189052,
#           0.09375171,  0.3154526 ]],
#
#        [[ 0.20563787, -0.5062881 , -1.0380452 , -0.35814187,
#           0.09386866,  0.3188918 ]]], shape=(808, 1, 6), dtype=float32)
